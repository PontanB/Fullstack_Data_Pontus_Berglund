# %%
import pandas as pd 

df_region = pd.read_csv("../../data/cleaned_yh_region.csv")
df_region
# Out:
#     Unnamed: 0  Blekinge  Dalarna  Gotland  Gävleborg  Halland  Jämtland  \
# 0         2007        14       21        0         15       14         9
# 1         2008        18       24        0         15       13         7
# 2         2009        13       21        0         16       13         5
# 3         2010         9       21        0         14       17         6
# 4         2011        12       22        1         10       18         6
# 5         2012         8       28        1         10        9         7
# 6         2013         8       35        0         14       20         9
# 7         2014         9       24        0         15       19         8
# 8         2015         8       18        0         14       14         8
# 9         2016         8       16        1         15       17         7
# 10        2017         8       14        1         16       16         6
# 11        2018         8       15        3         20       18        12
# ...
